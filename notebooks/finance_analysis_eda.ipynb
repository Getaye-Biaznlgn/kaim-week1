# %%
import pandas as pd
import numpy as np
# import seaborn as sns
import matplotlib.pyplot as plt
# from scipy import stats

import sys
sys.path.append("../scripts")
from quant_analysis import QuantitativeAnalysis

# %%
df = pd.read_csv('../data/raw_analyst_ratings.csv')
assert not df.empty, "Data import failed - DataFrame is empty!"

# %%
# Create analyzer instance
analyzer = QuantitativeAnalysis(df)

# %% [markdown]
# # Calculate and describe headline lengths

# %%
# Calculate and describe headline lengths
analyzer.calculate_headline_length()
analyzer.describe_headline_length()
analyzer.plot_headline_length_distribution()
# Out:
# [INFO] Headline length column created.
# [INFO] Headline Length Description:
#  count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# # Count articles per publisher

# %%
publisher_counts = analyzer.count_articles_per_publisher(top_n=10)
# Out:
# [INFO] Top 10 publishers by article count:
#  publisher
# paul quintaro        228373
# lisa levin           186979
# benzinga newsdesk    150484
# charles gross         96732
# monica gerson         82380
# eddie staley          57254
# hal lindon            49047
# etf professor         28489
# juan lopez            28438
# benzinga staff        28114
# Name: count, dtype: int64
# c:\Users\hp\keep_it\Tenx\kaim-week1\notebooks\../scripts\quant_analysis.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=publisher_counts.head(top_n).values,

# %% [markdown]
# # Analyze publication trends

# %%
daily_counts = analyzer.analyze_publication_trends()
monthly_counts = analyzer.analyze_publication_trends("M")
weekly_counts = analyzer.analyze_publication_trends("W")
weekly_counts.tail()
# Out:
# c:\Users\hp\keep_it\Tenx\kaim-week1\notebooks\../scripts\quant_analysis.py:101: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   trend = self.df.set_index('date').resample(frequency).size()
# date
# 2020-05-17 00:00:00+00:00    4380
# 2020-05-24 00:00:00+00:00    3567
# 2020-05-31 00:00:00+00:00    3163
# 2020-06-07 00:00:00+00:00    3528
# 2020-06-14 00:00:00+00:00    2919
# Freq: W-SUN, dtype: int64
